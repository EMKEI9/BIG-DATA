# %% [markdown]
# <a href="https://colab.research.google.com/github/EMKEI9/BIG-DATA/blob/master/%EC%9D%B4%EB%AF%B8%EC%A7%80%EC%B2%98%EB%A6%AC_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q mahotas

# %%
import mahotas as mh

# %%
from matplotlib import pyplot as pt

# %%
# %matplotlib inline

# %%
image = mh.imread('na.jpg')

# %%
pt.figure(figsize=(8,8))
pt.imshow(image)
pt.show()
