# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Crime_Seoul = pd.read_excel('../Data/서울시 5대범죄 발생장소별 현황 통계(장소별).xls', 
                            encoding = 'utf-8')

Crime_Seoul.head()
# Out:
#      기간      구분       계  아파트 연립다세대  단독주택     노상    상점  숙박업소목욕탕  유흥접객업소   사무실  \
# 0  2017       계  107835       4523  5092  32063  5047     1437    5077  1772
# 1  2017      살인     142         21    25     27     1        5      10     5
# 2  2017      강도     169         20    11     43    22        8       5     5
# 3  2017  강간강제추행    6963        319   413   1061   116      408     495   130
# 4  2017      절도   41162       1209  1340   8255  4119      670    1809   564
#
#    역대합실  교통수단  유원지   학교  금융기관     기타
# 0   908  2359  754  518  1024  47261
# 1     0     1    1    0     0     46
# 2     1     0    1    0     3     50
# 3   242  1105   51   49     1   2573
# 4   335   744  282  247   990  20598

# %%
Crime_Seoul.drop([0], inplace=True)
Crime_Seoul
# Out:
#      기간      구분      계  아파트 연립다세대  단독주택     노상    상점  숙박업소목욕탕  유흥접객업소   사무실  \
# 1  2017      살인    142         21    25     27     1        5      10     5
# 2  2017      강도    169         20    11     43    22        8       5     5
# 3  2017  강간강제추행   6963        319   413   1061   116      408     495   130
# 4  2017      절도  41162       1209  1340   8255  4119      670    1809   564
# 5  2017      폭력  59399       2954  3303  22677   789      346    2758  1068
#
#    역대합실  교통수단  유원지   학교  금융기관     기타
# 1     0     1    1    0     0     46
# 2     1     0    1    0     3     50
# 3   242  1105   51   49     1   2573
# 4   335   744  282  247   990  20598
# 5   330   509  419  222    30  23994

# %%
import numpy as np

# %%
import platform

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
plt.figure()
Crime_Seoul['계'].plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %%
Crime_Seoul.set_index('구분', inplace=True)

# %%
Crime_Seoul
# Out:
#           기간      계  아파트 연립다세대  단독주택     노상    상점  숙박업소목욕탕  유흥접객업소   사무실  \
# 구분
# 살인      2017    142         21    25     27     1        5      10     5
# 강도      2017    169         20    11     43    22        8       5     5
# 강간강제추행  2017   6963        319   413   1061   116      408     495   130
# 절도      2017  41162       1209  1340   8255  4119      670    1809   564
# 폭력      2017  59399       2954  3303  22677   789      346    2758  1068
#
#         역대합실  교통수단  유원지   학교  금융기관     기타
# 구분
# 살인         0     1    1    0     0     46
# 강도         1     0    1    0     3     50
# 강간강제추행   242  1105   51   49     1   2573
# 절도       335   744  282  247   990  20598
# 폭력       330   509  419  222    30  23994

# %%
np.corrcoef(Crime_Seoul['구분'], Crime_Seoul['아파트 연립다세대'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '구분'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-e77280f0a44f> in <module>()
# ...
